# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
from matplotlib import *
def menu():
  print("""
  Escoja una de las siguientes utilidades de la aplicacion 
  
  Menú

  1. Calculadora de polarizaciones básicas DC de transistor BJT.
  2. Calculadora de Valor Ohmico por bandas.
  3. Calculadora ley de ohm para circuitos de 4 resistencias y fuente de voltaje DC.
  4. Calculadora de amplificación en Cascada de transistores BJT.
  5. Calculadora de resistencias equivalentes.
  6. Calculadora de resistencia de un sistema.

  """)
def polarizacion(): #escogencia de configuracion y calculo de polarizacion
  print("""
      Escoja una de las siguientes utilidades de la aplicacion 
    
      Menú

      1. Polarización universal.
      2. Polarización base común.
      3. Polarización emisor común con resistencia de emisor.
      4. Polarización emisor común.
      """)
  print("Por favor ingrese el numero de la configuracion que desea calcular")
  def p_u(): #funcion de polarizacion universal
    print("haha")
  def p_b_c(): #funcion de polarizacion base comun
    print("hehe")
  def p_e_c_r_e(): #funcion de polarizacion emisor comun con resistencia de emisor
    print("hihi")
  def p_e_c(): #funcion de polarizacion emisor comun
    print("hoho")
  try:
      c = int(input())
  except ValueError:
      print("por favor ingrese un dato valido")
      cond = True
      fin = cond
      while(fin == True):
        try:
           c = int(input())
           if(type(c)==int):
            fin=False
        except ValueError:
           print("por favor ingrese un dato valido")
           fin = True
  if (c==1):
    return p_u()
  if (c==2):
    return p_b_c()
  if (c==3):
    return p_e_c_r_e()
  if (c==4):
    return p_e_c()


def bandas(): #calculo de resistencia por codigo de colores
  print("""
      Escoja el tipo de resistencias 
    
      Menú

      1. 4 bandas.
      2. 5 bandas.
      """)


def C_ley_de_ohm_r_VDC():#calculo de magnitudes presentes en un circuito VDC
  print("""
      Escoja el tipo basico de circuito de resistencias, estas pueden ser de cualquier valor real 
    
      Menú
        
      1. 4 Resistencias en paralelo.
      1. Resistencias 1 y 2 en serie y 3 y 4 en paralelo.
      1. Resistencias 1 y 2 en paralelo y 3 y 4 en serie.
      1. 4 Resistencias en serie.
      """)


def C_amp_en_Cda_BJT():
  print("""
      Escoja la combinacion de polarizaciones ofrecida 
    
      Menú
        
      1. Fase I Polarizacion Universal Fase II Polarizacion Universal
      2. Fase I Polarizacion Universal Fase II Emisor comun con resistencia de emisor
      3. Fase I Polarizacion Universal Fase II Emisor comun
      
      """)


def C_r_eq():
  print("""
      Escoja la conversion de escalas ofrecida 
    
      Menú
        
      1. KiloOhmios a Ohmios
      2. MegaOhmios a Ohmios
      3. miliOhmios a Ohmios
      4. Ohmios a KiloOhmios
      5. Ohmios a MegaOhmios
      6. Ohmios a miliOhmios  
      """)


def C_r_s():
  print("hoho")


def seleccion():#funcion de seleccion de utilidades generales
  print("Por favor ingrese el numero de la herramienta que desea utilizar")
  try:
      s = int(input())
  except ValueError:
      print("por favor ingrese un dato valido")
      cond = True
      fin = cond
      while(fin == True):
        try:
           s = int(input())
           if(type(s)==int):
            fin=False
        except ValueError:
           print("por favor ingrese un dato valido")
           fin = True
  if (s==1):
    return polarizacion()
  if (s==2):
    return bandas()
  if (s==3):
    return C_ley_de_ohm_r_VDC()
  if (s==4):
    return C_amp_en_Cda_BJT()
  if (s==5):
    return C_r_eq()
  if (s==6):
    return C_r_s()

def main():
  menu()
  seleccion()
main()
